# %%
from across.client import Client
from pandora_across_client_example.ingest import ingest


client = Client()
file_path = "/Users/sdwyatt/Work/git-clones/pandora-across-client-example/data/PAN-SCICAL-COM-20260527-VF-20260601-EX-20260608-R001_jpredits_cleaned00.xml"
with open(file_path, "r", encoding="utf-8") as xml_file:
    ingest(xml_file, client=client)
